# %%
import numpy as np
import pandas as pd

# %%
ser1=pd.Series([100,200,300],['xx','yy','zz']) #series

# %%
ser1
# Out:
# xx    100
# yy    200
# zz    300
# dtype: int64

# %%
ser1['xx']
# Out:
# np.int64(100)

# %%
ser1.iloc[1].item()
# Out:
# 200

# %%
ser1.iloc[2]
# Out:
# np.int64(300)

# %%
ser1.index
# Out:
# Index(['xx', 'yy', 'zz'], dtype='str')

# %%
d={'one':pd.Series([100,200,300],index=['apple','ball','clock']),
   'two':pd.Series([111,222,333,4444],index=['apple','ball','ceril','dancy'])}

# %%
d
# Out:
# {'one': apple    100
#  ball     200
#  clock    300
#  dtype: int64,
#  'two': apple     111
#  ball      222
#  ceril     333
#  dancy    4444
#  dtype: int64}

# %%
df=pd.DataFrame(d)
df
# Out:
#          one     two
# apple  100.0   111.0
# ball   200.0   222.0
# ceril    NaN   333.0
# clock  300.0     NaN
# dancy    NaN  4444.0

# %%
df['one']
# Out:
# apple    100.0
# ball     200.0
# ceril      NaN
# clock    300.0
# dancy      NaN
# Name: one, dtype: float64

# %%
df['one']['ball']
# Out:
# np.float64(200.0)

# %%
df['three']=df['one']=df['two']

# %%
df
# Out:
#           one     two   three
# apple   111.0   111.0   111.0
# ball    222.0   222.0   222.0
# ceril   333.0   333.0   333.0
# clock     NaN     NaN     NaN
# dancy  4444.0  4444.0  4444.0

# %%
df.insert(1,'copy_of_one',df['one'])
df
# Out:
#           one  copy_of_one     two   three
# apple   111.0        111.0   111.0   111.0
# ball    222.0        222.0   222.0   222.0
# ceril   333.0        333.0   333.0   333.0
# clock     NaN          NaN     NaN     NaN
# dancy  4444.0       4444.0  4444.0  4444.0

# %%
df['one_lower_half']=df['one'][:2]
df
# Out:
#           one  copy_of_one     two   three  one_lower_half
# apple   111.0        111.0   111.0   111.0           111.0
# ball    222.0        222.0   222.0   222.0           222.0
# ceril   333.0        333.0   333.0   333.0             NaN
# clock     NaN          NaN     NaN     NaN             NaN
# dancy  4444.0       4444.0  4444.0  4444.0             NaN

# %%
df['filet1']=(df['two']%2==0)
df
# Out:
#           one  copy_of_one     two   three  one_lower_half  filet1
# apple   111.0        111.0   111.0   111.0           111.0   False
# ball    222.0        222.0   222.0   222.0           222.0    True
# ceril   333.0        333.0   333.0   333.0             NaN   False
# clock     NaN          NaN     NaN     NaN             NaN   False
# dancy  4444.0       4444.0  4444.0  4444.0             NaN    True

# %%
import os

# %%
os.chdir("C:\\Users\\ASUS\\Downloads\\ml-latest-small\\ml-latest-small")

# %%
movies=pd.read_csv('movies.csv')

# %%
movies.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# ...

# %%
ratings=pd.read_csv('ratings.csv')

# %%
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
tags=pd.read_csv('tags.csv')

# %%
tags.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
movies.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9742 entries, 0 to 9741
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  9742 non-null   int64
#  1   title    9742 non-null   str
#  2   genres   9742 non-null   str
# dtypes: int64(1), str(2)
# memory usage: 626.1 KB

# %%
ratings.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   userId     100836 non-null  int64
#  1   movieId    100836 non-null  int64
#  2   rating     100836 non-null  float64
#  3   timestamp  100836 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 3.1 MB

# %%
ratings.describe()
# Out:
#               userId        movieId         rating     timestamp
# count  100836.000000  100836.000000  100836.000000  1.008360e+05
# mean      326.127564   19435.295718       3.501557  1.205946e+09
# std       182.618491   35530.987199       1.042529  2.162610e+08
# min         1.000000       1.000000       0.500000  8.281246e+08
# 25%       177.000000    1199.000000       3.000000  1.019124e+09
# 50%       325.000000    2991.000000       3.500000  1.186087e+09
# 75%       477.000000    8122.000000       4.000000  1.435994e+09
# max       610.000000  193609.000000       5.000000  1.537799e+09

# %%
ratings['rating'].mean()
# Out:
# np.float64(3.501556983616962)

# %%
ratings['rating'].max()
# Out:
# 5.0

# %%
ratings['rating'].mean()
# Out:
# np.float64(3.501556983616962)

# %%
is_highly_rated=ratings['rating']>=5.0

# %%
ratings[is_highly_rated]
# Out:
#         userId  movieId  rating   timestamp
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# 6            1      101     5.0   964980868
# 8            1      151     5.0   964984041
# 9            1      157     5.0   964984100
# ...        ...      ...     ...         ...
# 100814     610   158238     5.0  1479545219
# 100829     610   164179     5.0  1493845631
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
#
# [13211 rows x 4 columns]

# %%
avg_rating=ratings[['movieId','rating']].groupby('movieId').mean()

# %%
avg_rating.head()
# Out:
#            rating
# movieId
# 1        3.920930
# 2        3.431818
# 3        3.259615
# 4        2.357143
# 5        3.071429

# %%
avg_rating=ratings[['movieId','rating']].groupby('movieId').count()
avg_rating.head()
# Out:
#          rating
# movieId
# 1           215
# 2           110
# 3            52
# 4             7
# 5            49

# %%
t=movies.merge(ratings,on='movieId',how='inner')

# %%
t
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100831   193581  Black Butler: Book of the Atlantic (2017)
# 100832   193583               No Game No Life: Zero (2017)
# 100833   193585                               Flint (2017)
# 100834   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# ...

# %%
t1=movies.merge(ratings,on='movieId',how='left')
t1
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100849   193581  Black Butler: Book of the Atlantic (2017)
# 100850   193583               No Game No Life: Zero (2017)
# 100851   193585                               Flint (2017)
# 100852   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100853   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy     1.0     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy     5.0     4.0
# ...

# %%
t2=movies.merge(ratings,on='movieId',how='right')
t2
# Out:
#         movieId                           title  \
# 0             1                Toy Story (1995)
# 1             3         Grumpier Old Men (1995)
# 2             6                     Heat (1995)
# 3            47     Seven (a.k.a. Se7en) (1995)
# 4            50      Usual Suspects, The (1995)
# ...         ...                             ...
# 100831   166534                    Split (2017)
# 100832   168248   John Wick: Chapter Two (2017)
# 100833   168250                  Get Out (2017)
# 100834   168252                    Logan (2017)
# 100835   170875  The Fate of the Furious (2017)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1                                    Comedy|Romance       1     4.0
# 2                             Action|Crime|Thriller       1     4.0
# 3                                  Mystery|Thriller       1     5.0
# ...

# %%
t3=movies.merge(ratings,on='movieId',how='outer')
t3
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100849   193581  Black Butler: Book of the Atlantic (2017)
# 100850   193583               No Game No Life: Zero (2017)
# 100851   193585                               Flint (2017)
# 100852   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100853   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy     1.0     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy     5.0     4.0
# ...

# %%
avg_ratings=ratings.groupby('movieId').mean()
avg_ratings
# Out:
#              userId    rating     timestamp
# movieId
# 1        306.530233  3.920930  1.129835e+09
# 2        329.554545  3.431818  1.135805e+09
# 3        283.596154  3.259615  1.005110e+09
# 4        219.857143  2.357143  8.985789e+08
# 5        299.571429  3.071429  9.926643e+08
# ...             ...       ...           ...
# 193581   184.000000  4.000000  1.537109e+09
# 193583   184.000000  3.500000  1.537110e+09
# 193585   184.000000  3.500000  1.537110e+09
# 193587   184.000000  3.500000  1.537110e+09
# 193609   331.000000  4.000000  1.537158e+09
#
# [9724 rows x 3 columns]

# %%
box_office=movies.merge(avg_ratings,on='movieId',how='inner')
box_office.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres      userId    rating  \
# 0  Adventure|Animation|Children|Comedy|Fantasy  306.530233  3.920930
# 1                   Adventure|Children|Fantasy  329.554545  3.431818
# 2                               Comedy|Romance  283.596154  3.259615
# 3                         Comedy|Drama|Romance  219.857143  2.357143
# 4                                       Comedy  299.571429  3.071429
#
#       timestamp
# 0  1.129835e+09
# 1  1.135805e+09
# 2  1.005110e+09
# 3  8.985789e+08
# 4  9.926643e+08

# %%
is_highly_rated=box_office['rating']>=4.0

# %%
box_office[is_highly_rated]
# Out:
#       movieId                                              title  \
# 27         28                                  Persuasion (1995)
# 28         29  City of Lost Children, The (Cité des enfants p...
# 36         40                    Cry, the Beloved Country (1995)
# 46         50                         Usual Suspects, The (1995)
# 48         53                                    Lamerica (1994)
# ...       ...                                                ...
# 9713   191005                                     Gintama (2017)
# 9716   193571                                Silver Spoon (2014)
# 9717   193573            Love Live! The School Idol Movie (2015)
# 9719   193581          Black Butler: Book of the Atlantic (2017)
# 9723   193609                Andrew Dice Clay: Dice Rules (1991)
#
#                                       genres      userId    rating  \
# 27                             Drama|Romance  382.636364  4.227273
# ...
